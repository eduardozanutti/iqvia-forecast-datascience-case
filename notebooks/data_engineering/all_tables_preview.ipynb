# %%
import pandas as pd

df_dim_product = pd.read_parquet('../../data/gold/data_warehouse/dw_dim_product.parquet')
df_dim_region = pd.read_parquet('../../data/gold/data_warehouse/dw_dim_region.parquet')
df_dim_supplier = pd.read_parquet('../../data/gold/data_warehouse/dw_dim_supplier.parquet')
df_dim_time_series = pd.read_parquet('../../data/gold/data_warehouse/dw_dim_time_series.parquet')  
df_dim_weekly_calendar = pd.read_parquet('../../data/gold/data_warehouse/dw_dim_weekly_calendar.parquet')
df_fact_sales_weekly = pd.read_parquet('../../data/gold/data_warehouse/dw_fact_sales_weekly.parquet')

#datasets
df_base_dataset = pd.read_parquet('../../data/gold/forecasting/datasets/ds_base_dataset.parquet')
df_ds_erratic_base_time_series = pd.read_parquet('../../data/gold/forecasting/datasets/ds_erratic_base_timeseries.parquet')
df_ds_intermittent_base_time_series = pd.read_parquet('../../data/gold/forecasting/datasets/ds_intermittent_base_timeseries.parquet')
df_ds_lumpy_base_time_series = pd.read_parquet('../../data/gold/forecasting/datasets/ds_lumpy_base_timeseries.parquet')
df_ds_segmented_time_series = pd.read_parquet('../../data/gold/forecasting/datasets/ds_segmented_time_series.parquet')
df_ds_smooth_base_time_series = pd.read_parquet('../../data/gold/forecasting/datasets/ds_smooth_base_timeseries.parquet')

#features
df_time_series_lag_features = pd.read_parquet('../../data/gold/forecasting/features/ds_time_series_lag_features.parquet')
df_time_series_product_features = pd.read_parquet('../../data/gold/forecasting/features/ds_time_series_product_features.parquet')
df_time_series_statistical_features = pd.read_parquet('../../data/gold/forecasting/features/ds_time_series_statistical_features.parquet')
df_time_series_time_features = pd.read_parquet('../../data/gold/forecasting/features/ds_time_series_time_features.parquet')

#tags
df_time_series_outliers_detected = pd.read_parquet('../../data/gold/forecasting/tags/ds_time_series_outliers_detected.parquet')
df_time_series_segmented_classified = pd.read_parquet('../../data/gold/forecasting/tags/ds_time_series_segmented_classified.parquet')
df_time_series_outliers_detected = pd.read_parquet('../../data/gold/forecasting/tags/ds_time_series_outliers_detected.parquet')

# %%
df_dim_product.head(5)
# Out:
#    product_id product_attribute_1 product_attribute_2 product_attribute_3  \
# 0           1                   B                   C                 B24
# 1           2                   B                   C                 B16
# 2           3                   A                   A                 A08
# 3           4                   B                   C                 B24
# 4           5                   B                   C                 B32
#
#   product_name
# 0    Product 1
# 1    Product 2
# 2    Product 3
# 3    Product 4
# 4    Product 5

# %%
df_dim_region.head(5)
# Out:
#    region_id   region_name
# 0          1  Centro-Oeste
# 1          2      Nordeste
# 2          3         Norte
# 3          4       Sudeste
# 4          5           Sul

# %%
df_dim_supplier.head(5)
# Out:
#    supplier_id supplier_name
# 0            1    Supplier 1
# 1            2    Supplier 2
# 2            3    Supplier 3
# 3            4    Supplier 4
# 4            5    Supplier 5

# %%
df_dim_time_series.head(5)
# Out:
#    time_series_id  supplier_id  region_id  product_id first_week_date  \
# 0               1            1          5          69      2023-01-09
# 1               2            1          5          89      2023-03-06
# 2               3            1          5          97      2022-10-31
# 3               4            1          5         121      2022-10-31
# 4               5            1          5         134      2022-10-31
#
#   last_week_date  total_weeks_length  num_week_with_sales  \
# 0     2023-08-21                  33                    4
# 1     2024-10-21                  86                   33
# 2     2023-01-30                  14                    3
# 3     2024-10-21                 104                   83
# 4     2024-10-21                 104                   48
#
#    num_week_with_zeros  sales_units  ...  std_weekly_sales  \
# 0                   29         10.0  ...          1.103541
# 1                   53       1716.0  ...         65.791275
# ...

# %%
df_dim_weekly_calendar.head(5)
# Out:
#    week_date  week start_date   end_date  year  semester semester_date  \
# 0 2022-10-31    44 2022-10-31 2022-11-06  2022         2    2022-10-01
# 1 2022-11-07    45 2022-11-07 2022-11-13  2022         2    2022-11-01
# 2 2022-11-14    46 2022-11-14 2022-11-20  2022         2    2022-11-01
# 3 2022-11-21    47 2022-11-21 2022-11-27  2022         2    2022-11-01
# 4 2022-11-28    48 2022-11-28 2022-12-04  2022         2    2022-11-01
#
#   semester_name  quarter quarter_date quarter_name  month month_name  \
# 0            H2        4   2022-10-01           Q4     10    October
# 1            H2        4   2022-10-01           Q4     11   November
# 2            H2        4   2022-10-01           Q4     11   November
# 3            H2        4   2022-10-01           Q4     11   November
# 4            H2        4   2022-10-01           Q4     11   November
#
#   month_date
# 0 2022-10-01
# 1 2022-11-01
# 2 2022-11-01
# 3 2022-11-01
# 4 2022-11-01

# %%
df_fact_sales_weekly.head(5)
# Out:
#    week_date  supplier_id  region_id  product_id  time_series_id  units_sold
# 0 2022-10-31            1          5          97               3           2
# 1 2022-10-31            1          5         121               4          61
# 2 2022-10-31            1          5         134               5         189
# 3 2022-10-31            1          5         241              12        5064
# 4 2022-10-31            1          5         246              13          22

# %%
df_base_dataset.head(5)
# Out:
#    time_series_id  week_date  supplier_id  region_id  product_id  units_sold  \
# 0               1 2023-01-09            1          5          69           2
# 1               1 2023-01-16            1          5          69           6
# 2               1 2023-01-23            1          5          69           0
# 3               1 2023-01-30            1          5          69           0
# 4               1 2023-02-06            1          5          69           0
#
#    week start_date   end_date  year  ...  q50_sales q75_sales  iqr        cv  \
# 0     2 2023-01-09 2023-01-15  2023  ...          0         0  0.0  3.641674
# 1     3 2023-01-16 2023-01-22  2023  ...          0         0  0.0  3.641674
# 2     4 2023-01-23 2023-01-29  2023  ...          0         0  0.0  3.641674
# 3     5 2023-01-30 2023-02-05  2023  ...          0         0  0.0  3.641674
# 4     6 2023-02-06 2023-02-12  2023  ...          0         0  0.0  3.641674
#
# ...

# %%
df_ds_erratic_base_time_series.head(5)
# Out:
#    time_series_id  week_date  supplier_id  region_id  product_id  units_sold  \
# 0               4 2022-10-31            1          5         121          61
# 1               4 2022-11-07            1          5         121           9
# 2               4 2022-11-14            1          5         121          18
# 3               4 2022-11-21            1          5         121           3
# 4               4 2022-11-28            1          5         121           8
#
#    week start_date   end_date  year  ...  q75_sales    iqr        cv  \
# 0    44 2022-10-31 2022-11-06  2022  ...        145  128.0  0.942753
# 1    45 2022-11-07 2022-11-13  2022  ...        145  128.0  0.942753
# 2    46 2022-11-14 2022-11-20  2022  ...        145  128.0  0.942753
# 3    47 2022-11-21 2022-11-27  2022  ...        145  128.0  0.942753
# 4    48 2022-11-28 2022-12-04  2022  ...        145  128.0  0.942753
#
#    supplier_name region_name product_name  product_attribute_1  \
# ...

# %%
df_ds_intermittent_base_time_series.head(5)
# Out:
#    time_series_id  week_date  supplier_id  region_id  product_id  units_sold  \
# 0               3 2022-10-31            1          5          97           2
# 1               3 2022-11-07            1          5          97           0
# 2               3 2022-11-14            1          5          97           0
# 3               3 2022-11-21            1          5          97           0
# 4               3 2022-11-28            1          5          97           0
#
#    week start_date   end_date  year  ...  q75_sales  iqr        cv  \
# 0    44 2022-10-31 2022-11-06  2022  ...          0  0.0  2.085844
# 1    45 2022-11-07 2022-11-13  2022  ...          0  0.0  2.085844
# 2    46 2022-11-14 2022-11-20  2022  ...          0  0.0  2.085844
# 3    47 2022-11-21 2022-11-27  2022  ...          0  0.0  2.085844
# 4    48 2022-11-28 2022-12-04  2022  ...          0  0.0  2.085844
#
#    supplier_name region_name product_name  product_attribute_1  \
# ...

# %%
df_ds_lumpy_base_time_series.head(5)
# Out:
#    time_series_id  week_date  supplier_id  region_id  product_id  units_sold  \
# 0               1 2023-01-09            1          5          69           2
# 1               1 2023-01-16            1          5          69           6
# 2               1 2023-01-23            1          5          69           0
# 3               1 2023-01-30            1          5          69           0
# 4               1 2023-02-06            1          5          69           0
#
#    week start_date   end_date  year  ...  q75_sales  iqr        cv  \
# 0     2 2023-01-09 2023-01-15  2023  ...          0  0.0  3.641674
# 1     3 2023-01-16 2023-01-22  2023  ...          0  0.0  3.641674
# 2     4 2023-01-23 2023-01-29  2023  ...          0  0.0  3.641674
# 3     5 2023-01-30 2023-02-05  2023  ...          0  0.0  3.641674
# 4     6 2023-02-06 2023-02-12  2023  ...          0  0.0  3.641674
#
#    supplier_name region_name product_name  product_attribute_1  \
# ...

# %%
df_ds_segmented_time_series.head(5)
# Out:
#    time_series_id       segment
# 0               1  discontinued
# 1               2         valid
# 2               3  discontinued
# 3               4         valid
# 4               5         valid

# %%
df_ds_smooth_base_time_series.head(5)
# Out:
#    time_series_id  week_date  supplier_id  region_id  product_id  units_sold  \
# 0               9 2023-05-01            1          5         185          18
# 1               9 2023-05-08            1          5         185          14
# 2              15 2022-10-31            1          5         289           4
# 3              16 2024-07-01            1          5         294           3
# 4              16 2024-07-08            1          5         294           1
#
#    week start_date   end_date  year  ...  q75_sales  iqr        cv  \
# 0    18 2023-05-01 2023-05-07  2023  ...         17  2.0  0.176777
# 1    19 2023-05-08 2023-05-14  2023  ...         17  2.0  0.176777
# 2    44 2022-10-31 2022-11-06  2022  ...          4  0.0  0.000000
# 3    27 2024-07-01 2024-07-07  2024  ...          3  2.0  0.912870
# 4    28 2024-07-08 2024-07-14  2024  ...          3  2.0  0.912870
#
#    supplier_name region_name product_name  product_attribute_1  \
# ...

# %%
df_time_series_lag_features.head(5)
# Out:
#    time_series_id  week_date  units_sold  lag_4  lag_5  lag_13  lag_14  \
# 0               2 2023-03-06          28   <NA>   <NA>    <NA>    <NA>
# 1               2 2023-03-13          11   <NA>   <NA>    <NA>    <NA>
# 2               2 2023-03-20          24   <NA>   <NA>    <NA>    <NA>
# 3               2 2023-03-27          48   <NA>   <NA>    <NA>    <NA>
# 4               2 2023-04-03           6     28   <NA>    <NA>    <NA>
#
#    lag_27  lag_28  lag_52
# 0    <NA>    <NA>    <NA>
# 1    <NA>    <NA>    <NA>
# 2    <NA>    <NA>    <NA>
# 3    <NA>    <NA>    <NA>
# 4    <NA>    <NA>    <NA>

# %%
df_time_series_product_features.head(5)
# Out:
#    time_series_id product_attribute_1 product_attribute_2 product_attribute_3
# 0               2                   A                   A                 A01
# 1               4                   C                   B                 B02
# 2               5                   C                   B                 B02
# 3               7                   C                   B                 B02
# 4              12                   A                   A                 A05

# %%
df_time_series_statistical_features.head(5)
# Out:
#    time_series_id  avg_weekly_sales  avg_weekly_sales_non_zero  \
# 0               2         19.953489                  52.000000
# 1               4         95.826920                 120.072289
# 2               5        136.615387                 296.000000
# 3               7          0.520548                   1.727273
# 4              12       1657.442261                1758.918367
#
#    std_weekly_sales  std_weekly_sales_non_zero  max_weekly_sales  \
# 0         65.791275                  98.889142               375
# 1         90.341148                  85.469119               393
# 2        670.247131                 967.627918              5646
# 3          1.313494                   1.931735                10
# 4       2018.142334                2035.805029             11981
#
#    min_weekly_sales  q25_sales  q50_sales  q75_sales      iqr        cv
# 0                 0          0          0          6     6.00  3.297232
# ...

# %%
df_time_series_time_features.head(5)
# Out:
#    time_series_id  week_date  year  semester  quarter  month  week
# 0               2 2023-03-06  2023         1        1      3    10
# 1               2 2023-03-13  2023         1        1      3    11
# 2               2 2023-03-20  2023         1        1      3    12
# 3               2 2023-03-27  2023         1        1      3    13
# 4               2 2023-04-03  2023         1        2      4    14

# %%
df_time_series_outliers_detected.head(5)
# Out:
#     week_date  time_series_id  units_sold segment  is_outlier  \
# 33 2023-03-06               2          28   valid       False
# 34 2023-03-13               2          11   valid       False
# 35 2023-03-20               2          24   valid       False
# 36 2023-03-27               2          48   valid       False
# 37 2023-04-03               2           6   valid       False
#
#     rolling_baseline  upper_threshold  lower_threshold  units_sold_original  \
# 33              20.0          60.0302              0.0                 28.0
# 34              20.0          60.0302              0.0                 11.0
# 35              22.0          82.0453              0.0                 24.0
# 36              22.0          82.0453              0.0                 48.0
# 37              22.0          82.0453              0.0                  6.0
#
#     units_sold_capped  units_sold_removed  units_sold_interpolated
# 33               28.0                28.0                     28.0
# ...

# %%
df_time_series_segmented_classified.head(5)
# Out:
#    time_series_id       segment demand_type sugested_model
# 0               1  discontinued        None      end_cycle
# 1               2         valid       lumpy    statistical
# 2               3  discontinued        None      end_cycle
# 3               4         valid     erratic    statistical
# 4               5         valid       lumpy    statistical

# %%
df_time_series_outliers_detected.head(5)
# Out:
#     week_date  time_series_id  units_sold segment  is_outlier  \
# 33 2023-03-06               2          28   valid       False
# 34 2023-03-13               2          11   valid       False
# 35 2023-03-20               2          24   valid       False
# 36 2023-03-27               2          48   valid       False
# 37 2023-04-03               2           6   valid       False
#
#     rolling_baseline  upper_threshold  lower_threshold  units_sold_original  \
# 33              20.0          60.0302              0.0                 28.0
# 34              20.0          60.0302              0.0                 11.0
# 35              22.0          82.0453              0.0                 24.0
# 36              22.0          82.0453              0.0                 48.0
# 37              22.0          82.0453              0.0                  6.0
#
#     units_sold_capped  units_sold_removed  units_sold_interpolated
# 33               28.0                28.0                     28.0
# ...
