# %% [markdown]
# # Model Building and Evaluation
#
# **Task 3** — Variable selection, cross-validation, model choice and evaluation metric justification.

# %% [markdown]
# ## 1. Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yaml
import joblib

from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')

with open('../../config.yaml') as f:
    config = yaml.safe_load(f)

# %% [markdown]
# ## 2. Load Gold Data

# %%
df = pd.read_parquet('../../data/gold/features.parquet')
df.head()

# %% [markdown]
# ## 3. Variable Selection

# %%
TARGET = 'units_qty'
FEATURES = [col for col in df.columns if col != TARGET]

X = df[FEATURES]
y = df[TARGET]

# %% [markdown]
# ## 4. Cross-Validation Strategy
#
# For time series data, we use `TimeSeriesSplit` to avoid data leakage — future data must never be used to predict the past.

# %%
tscv = TimeSeriesSplit(n_splits=5)

for fold, (train_idx, val_idx) in enumerate(tscv.split(X)):
    print(f"Fold {fold+1}: train={len(train_idx)} | val={len(val_idx)}")

# %% [markdown]
# ## 5. Model Training
#
# **Chosen model:** _TBD_ (justify the choice here)
#
# **Evaluation metric:** _TBD_ (e.g., WMAPE, MAE — justify here)

# %%
# TODO: instantiate and train the chosen model
# model = ...
# model.fit(X_train, y_train)

# %% [markdown]
# ## 6. Evaluation

# %%
def wmape(y_true, y_pred):
    return np.sum(np.abs(y_true - y_pred)) / np.sum(np.abs(y_true))

# TODO: compute metrics per fold and overall

# %% [markdown]
# ## 7. Save Model

# %%
# joblib.dump(model, '../../models/forecast_model.joblib')
# print('Model saved.')
